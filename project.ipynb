# %% [markdown]
# # Real Estate Clean up
#
# This is a real dataset and it was downloaded using web scraping techniques. The data contains registers from fotocasa which is one of the most popular websites of real estate in Spain. Please, do not do this (web scraping) unless it is for academic purposes.
#
# The dataset was downloaded a few years ago by Henry Navarro and In no case were economic returns obtained from it.
#
# It contains thousands of data from real houses published on the web www.fotocasa.com. Your goal is to extract as much information as possible with the knowledge you have so far about data science, for example what is the most expensive house in the entire dataset?
#
# Let's start with precisely that question... Good luck!

# %% [markdown]
# #### Exercise 00. Read the dataset assets/real_estate.csv and try to visualize the table (★☆☆)

# %%
import pandas as pd
import shutil as sh
import matplotlib as mat

# this CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Exercise 01. Which is the most expensive house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address General Street Nº5 is the most expensive and its price is 5000000 USD`

# %%
# TODO
id_ds_max_price = ds.loc[:, ['price']].idxmax()
ds_max_price_Price = ds.loc[id_ds_max_price,['price']]
ds_max_price_Address = ds.loc[id_ds_max_price,['address']]
print("The house with adress : " + ds_max_price_Address.to_string(header=False,index=False) + " is the most expensive and its price is " + ds_max_price_Price.to_string(header=False,index=False) + " USD")
# Out:
# The house with adress : El Escorial is the most expensive and its price is 8500000 USD

# %% [markdown]
# #### Exercise 02. Which is cheapest house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address Concrete Street Nº1 is the cheapest and its price is 12000 USD`

# %%
# TODO

id_ds_min_price = ds.loc[:, ['price']].idxmin()
ds_min_price_Price = ds.loc[id_ds_min_price,['price']]
ds_min_price_Address = ds.loc[id_ds_min_price,['address']]
print("The house with adress : " + ds_min_price_Address.to_string(header=False,index=False) + " is the most cheapest and its price is " + ds_min_price_Price.to_string(header=False,index=False) + " USD")
# Out:
# The house with adress : Parla is the most cheapest and its price is 0 USD

# %% [markdown]
# #### Exercise 03. Which is the biggest and the smallest house in the dataset? (★☆☆)
#
# Print both the address and the surface of the selected houses. For example:
#
# `The bigger house is located on Yukka Street Nº10 and its surface is 5000 meters`
#
# `The smaller house is located on County Road 1 N and its surface is 200 meters`

# %%
# TODO

id_ds_smallest_surface = ds.loc[:, ['surface']].idxmin()
id_ds_biggest_surface = ds.loc[:, ['surface']].idxmax()

ds_smallest_surface = ds.loc[id_ds_smallest_surface,['surface']]
ds_smallest_surface_address = ds.loc[id_ds_smallest_surface,['address']]
ds_biggest_surface = ds.loc[id_ds_biggest_surface,['surface']]
ds_biggest_surface_address = ds.loc[id_ds_biggest_surface,['address']]

print("The bigger house is located on : " + ds_biggest_surface_address.to_string(header=False,index=False) + " and its surface is " + ds_biggest_surface.to_string(header=False,index=False) + " meters. The smaller house is located on  " + ds_smallest_surface_address.to_string(header=False,index=False) + " and its surface is " + ds_smallest_surface.to_string(header=False,index=False) + " meters")
# Out:
# The bigger house is located on : Sevilla la Nueva and its surface is 249000.0 meters. The smaller house is located on  Calle Amparo,  Madrid Capital and its surface is 15.0 meters

# %% [markdown]
# #### Exercise 04. How many populations (level5 column) the dataset contains? (★☆☆)
#
# Print the name of the populations with comma as separator. For example:
#
# `> print(populations)`
#
# `population1, population2, population3,...`

# %%
# TODO

serie_df = ds['level5'].squeeze()
serie_count = serie_df.count()
print( "The dataset contains " + str(serie_count) + " different populations and here they are: " + str(serie_df.values.tolist()) )
# Out:
# The dataset contains 15335 different populations and here they are: ['Arganda del Rey', 'Fuenlabrada', 'Boadilla del Monte', 'Fuenlabrada', 'Arganda del Rey', 'Las Rozas de Madrid', 'Las Rozas de Madrid', 'Las Rozas de Madrid', 'Las Rozas de Madrid', ' Madrid Capital', ' Madrid Capital', 'Villaviciosa de Odón', 'Pinto', 'Valdemoro', 'Navalcarnero', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', 'Pozuelo de Alarcón', 'Torrejón de Ardoz', 'Navalagamella', 'San Sebastián de los Reyes', ' Madrid Capital', 'Rivas-vaciamadrid', 'Alpedrete', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', 'Móstoles', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', 'San Fernando de Henares', 'Coslada', ' Madrid Capital', 'Becerril de la Sierra', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', ' Madrid Capital', 'Alcalá de Henares', ' Madrid Capital', ' Madrid Capital', ' Madrid 
# ...

# %% [markdown]
# #### Exercise 05. Does the dataset contain NAs? (★☆☆)
#
# Print a boolean value (`true` or `fase`) followed by the rows/cols that contains NAs.

# %%
# TODO

#Serie_Nans = []
#for col in ds.columns:
#    if ds[col].isnull().any():
#        Serie_Nans.append()
#print(Serie_Nans)
#print(ds.columns[ds.isna().any()].tolist())
#print(ds[1].isnull().any())

print(ds.isna())

#Print(which(is.na(ds)))
#print(ds.isna())
#ds.loc[ds.isna() ='True']
#print(ds.isna().any())
# Out:
#        Unnamed: 0  id_realEstates  isNew  realEstate_name  phone_realEstate  \
# 0           False           False  False            False             False
# 1           False           False  False            False             False
# 2           False           False  False            False             False
# 3           False           False  False            False             False
# 4           False           False  False            False             False
# ...           ...             ...    ...              ...               ...
# 15330       False           False  False            False             False
# 15331       False           False  False            False             False
# 15332       False           False  False            False             False
# 15333       False           False  False            False             False
# 15334       False           False  False            False             False
#
# ...

# %% [markdown]
# #### Exercise 06. Delete the NAs of the dataset, if applicable (★★☆)
#
# Print a comparison between the dimensions of the original DataFrame versus the DataFrame after the deletions

# %%
# TODO
print( "The full dataset dimensions are " + str(ds.shape) + " and if we clean the NAs the dataset dimensions are: " + str(ds.dropna().shape) )
# Out:
# The full dataset dimensions are (15335, 37) and if we clean the NAs the dataset dimensions are: (0, 37)

# %% [markdown]
# #### Exercise 07. Which is the mean of prices in the population (level5 column) of "Arroyomolinos (Madrid)"? (★★☆)
#
# Print the obtained value

# %%
# TODO
import statistics as st

ds_filtered = ds[ds['level5'] == "Arroyomolinos (Madrid)"] 
ds_filtered_mean = ds_filtered['price'].mean()
print("The mean of prices in Arroyomolinos (Madrid) population is " + str(ds_filtered_mean) )
# Out:
# The mean of prices in Arroyomolinos (Madrid) population is 294541.59854014596

# %% [markdown]
# #### Exercise 08. Plot the histogram of prices for the population (level5 column) of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)
#
# Print the histogram of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
# TODO: Code
ds_filtered = ds[ds['level5'] == "Arroyomolinos (Madrid)"] 
ds_filtered['price'].hist()
# Out:
# <Axes: >

# %% [markdown]
# This means that most of houses values has a price between 180.000 and 450.000 usd.

# %% [markdown]
# #### Exercise 09. Are the averages of "Valdemorillo" and "Galapagar" prices the same? (★★☆)
#
# Print the both average prices and then write a conclusion about them

# %%
# TODO

ds_filtered_Valde = ds[ds['level5'] == "Valdemorillo"] 
ds_filtered_Gala = ds[ds['level5'] == "Galapagar"] 


ds_filtered_Valde= ds_filtered_Valde['price'].mean()
ds_filtered_Gala= ds_filtered_Gala['price'].mean()
print("The average of Valdemorillo prices is " + str(ds_filtered_Valde) + ", the average of Galapagar prices is " + str(ds_filtered_Gala) 
+ ", this means that the cost in both areas is almost the same"      )
# Out:
# The average of Valdemorillo prices is 363860.2931034483, the average of Galapagar prices is 360063.20238095237, this means that the cost in both areas is almost the same

# %% [markdown]
# #### Exercise 10. Are the averages of "Valdemorillo" and "Galapagar" price per square meter (price/m2) the same? (★★☆)
#
# Print the both average prices and then write a conclusion about
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
# TODO
ds['pps'] = ds['price'] / ds['surface']  
ds_pps_Valde = ds['pps'][ds['level5'] == "Valdemorillo"].mean()
ds_pps_Gala = ds['pps'][ds['level5'] == "Galapagar"].mean()
print("The average of Valdemorillo prices per square meter is " + str(ds_pps_Valde) + ", the average of Galapagar pps is " + str(ds_pps_Gala) 
+ ", this means that the pps is expensiver in Galapagar")
# Out:
# The average of Valdemorillo prices per square meter is 1317.9502109024986, the average of Galapagar pps is 1606.3240303094024, this means that the pps is expensiver in Galapagar

# %% [markdown]
# #### Exercise 11. Analyse the relation between the surface and the price of the houses (★★☆)
#
# Hint: You can make a `scatter plot` and then write a conclusion about it

# %%
# TODO: Code
import matplotlib.pyplot as plt
import numpy as np

ds_filtered_price= ds['price']
ds_filtered_surface= ds['surface']
plt.scatter(ds_filtered_surface,ds_filtered_price)
plt.show()

# %% [markdown]
# We have high prices for a small area, so it is expensive.

# %% [markdown]
# #### Exercise 12. How many real estate agencies the dataset contains? (★★☆)
#
# Print the obtained value

# %%
# TODO
import pandas as pd

len(pd.unique(ds['id_realEstates']))
# Out:
# 14217

# %% [markdown]
# #### Exercise 13. Which is the population (level5 column) that contains the most houses? (★★☆)
#
# Print both the population and the number of houses

# %%
# TODO
#ds.groupby(ds['level5']).count()
max_value = ds['level5'].value_counts().max()
max_name = ds['level5'].value_counts().idxmax()
print("The population that contains the higher number of houses is " + str(max_name) + " with " + str(max_value) + " houses")
# Out:
# The population that contains the higher number of houses is  Madrid Capital with 6643 houses

# %% [markdown]
# #### Exercise 14. Now let's work with the "south belt" of madrid. Make a subset of the original DataFrame that contains the following populations (level5 column): "Fuenlabrada","Leganés","Getafe","Alcorcón" (★★☆)
#
# Hint: Filter the original DataFrame using the column `level5` and the function `isin`

# %%
# TODO

sub_ds = ds[ds["level5"].str.contains("Fuenlabrada|Leganés|Getafe|Alcorcón")]
print(sub_ds)
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %% [markdown]
# #### Exercise 15. Make a bar plot of the median of the prices and explain what you observe (you must use the subset obtained in the question 14) (★★★)
#
# Print the bar of the median of the prices and write in the Markdown cell a brief analysis about the plot

# %%
# TODO: Code
import matplotlib.pyplot as plt

sub_ds.groupby('level5')['price'].mean().plot.bar()



'''
# dataset filtrado
ds_new = ds[ds['level5'].str.contains("Fuenlabrada|Leganés|Getafe|Alcorcón")]

df_new = ds_new[['level5', 'price']].groupby('level5', group_keys=False).median()

df_new_pop = df_new['price']
print(df_new_pop)

plt.figure();

df_new_pop.plot.bar();

plt.axhline(0, color="k");
'''
# Out:
# '\n# dataset filtrado\nds_new = ds[ds[\'level5\'].str.contains("Fuenlabrada|Leganés|Getafe|Alcorcón")]\n\ndf_new = ds_new[[\'level5\', \'price\']].groupby(\'level5\', group_keys=False).median()\n\ndf_new_pop = df_new[\'price\']\nprint(df_new_pop)\n\nplt.figure();\n\ndf_new_pop.plot.bar();\n\nplt.axhline(0, color="k");\n'

# %% [markdown]
# #### Exercise 16. Calculate the sample mean and variance of the variables: price, rooms, surface area and bathrooms (you must use the subset obtained in the question 14) (★★★)
#
# Print both values for each variable

# %%
# TODO

print("The sample mean of price is: " + str(sub_ds.price.mean())  + " and the variance is: " + str(sub_ds.price.var()))

print("The sample mean of rooms is: " + str(sub_ds.rooms.mean())  + " and the variance is: " + str(sub_ds.rooms.var()))

print("The sample mean of surface is: " + str(sub_ds.surface.mean())  + " and the variance is: " + str(sub_ds.surface.var()))

print("The sample mean of prices is: " + str(sub_ds.bathrooms.mean())  + " and the variance is: " + str(sub_ds.bathrooms.var()))
# Out:
# The sample mean of price is: 223094.48070562293 and the variance is: 14921367508.04902
# The sample mean of rooms is: 3.0177383592017737 and the variance is: 0.7188858892927542
# The sample mean of surface is: 111.75222363405337 and the variance is: 4263.051760316337
# The sample mean of prices is: 1.633221850613155 and the variance is: 0.5717968625577321

# %% [markdown]
# #### Exercise 17. What is the most expensive house of each population? You must use the subset obtained in the question 14 (★★☆)
#
# Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population

# %%
# TODO
sub_ds[["level5","address", "price"]].groupby("level5").max()
# Out:
#                                                        address    price
# level5
# Alcorcón                         Travesia Nuncio del, Alcorcón   950000
# Fuenlabrada  Urbanización Urbanización Parque Miraflores, 5...   490000
# Getafe                                San Sebastián, 1, Getafe  1050000
# Leganés         Plaza Pza España, Gran Oportunidad!!!, Leganés   650000

# %% [markdown]
# #### Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in the question 14) (★★★)
#
# For the normalization method you can use the one you consider to, there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot
#
# Hint: You can help yourself reviewing the multihist demo of Matplotlib

# %%
# TODO

import numpy as np
import matplotlib.pyplot as plt

# Getafe
ds_filtered_Getafe = sub_ds[sub_ds['level5'] == "Getafe"] 
norm_price_getafe = ds_filtered_Getafe["price"]/ ds_filtered_Getafe["price"].max()

# AlcorcÃ³n 
ds_filtered_Alcor = sub_ds[sub_ds['level5'] == "Alcorcón"] 
norm_price_Alcor = ds_filtered_Alcor["price"]/ ds_filtered_Alcor["price"].max()

# Fuenlabrada
ds_filtered_Fuen = sub_ds[sub_ds['level5'] == "Fuenlabrada"] 
norm_price_Fuen = ds_filtered_Fuen["price"]/ ds_filtered_Fuen["price"].max()

# LeganÃ©s
ds_filtered_Lega = sub_ds[sub_ds['level5'] == "Leganés"] 
norm_price_Lega = ds_filtered_Lega["price"]/ ds_filtered_Lega["price"].max()


plt.figure(figsize = (10, 5))

plt.hist(norm_price_Lega, label = 'Leganés', bins = 30, alpha = 0.7)
plt.hist(norm_price_Alcor, label = 'Alcorcón', bins = 30, alpha = 0.7)
plt.hist(norm_price_Fuen,label = 'Fuenlabrada', bins = 30, alpha = 0.7)
plt.hist(norm_price_getafe, label = 'Getafe',bins = 30, alpha = 0.7)

plt.legend()
plt.title("Histogram")
plt.show()

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in the question 14 (★★☆)
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
# TODO


ds_filtered_Getafe = sub_ds[sub_ds['level5'] == "Getafe"].copy() 
ds_filtered_Getafe["pps"] = ds_filtered_Getafe['price'] /  ds_filtered_Getafe['surface']

ds_filtered_Alcor = sub_ds[sub_ds['level5'] == "Alcorcón"].copy() 
ds_filtered_Alcor["pps"] = ds_filtered_Alcor['price'] /  ds_filtered_Alcor['surface']

plt.figure(figsize = (10, 5))

plt.hist(ds_filtered_Alcor["pps"], label = 'Alcorcón', bins = 30, alpha = 0.7)
plt.hist(ds_filtered_Getafe["pps"], label = 'Getafe', bins = 30, alpha = 0.7)

plt.legend()
plt.title("Histogram")
plt.show()

# %% [markdown]
# #### Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph? You must use the subset obtained in the question 14 (★★☆)
# Hint: make a scatter plot of each population using subplots.

# %%
# TODO

import matplotlib.pyplot as plt
import numpy as np
import random 

plt.rcParams["figure.figsize"] = (10,6) 

plt.subplot(2,2,1)
x1=[ds_filtered_Getafe["price"]]
y1=[ds_filtered_Getafe["surface"]]
plt.scatter(x1,y1,label = 'Getafe', c='r')
plt.grid()
plt.legend()


plt.subplot(2,2,2)
x1=[ds_filtered_Alcor["price"]]
y1=[ds_filtered_Alcor["surface"]]
plt.scatter(x1,y1,label = 'Alcorcón',c='r')
plt.grid()
plt.legend()

plt.subplot(2,2,3)
x1=[ds_filtered_Fuen["price"]]
y1=[ds_filtered_Fuen["surface"]]
plt.scatter(x1,y1,label = 'Fuenlabrada',c='r')
plt.grid()
plt.legend()

plt.subplot(2,2,4)
x1=[ds_filtered_Lega["price"]]
y1=[ds_filtered_Lega["surface"]]
plt.scatter(x1,y1,label = 'Leganés',c='r')
plt.grid()
plt.legend()

# %% [markdown]
# #### Exercise 21. Make a plot of the coordinates (latitude and longitude columns) of the south belt of Madrid by color of each population (you must use the subset obtained in the question 14) (★★★★)
#
# Execute the following cell and then start coding in the next one. You must implement a simple code that transform the coordinates columns in a Python dictionary (add more information if needed) and then add it to the map

# %%
from ipyleaflet import Map, basemaps


from ipyleaflet import Map, basemaps, Marker

# Map centred on (60 degrees latitude et -2.2 degrees longitude)
# Latitude, longitude
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.Stadia.StamenTerrain)
map
# Out:
# Map(center=[60, -2.2], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
## HERE: plot the coordinates of the estates

sub_ds = sub_ds.copy() 
sub_ds["latitude"] = sub_ds["latitude"].str.replace(",", ".")
sub_ds["longitude"] = sub_ds["longitude"].str.replace(",", ".")

coord = sub_ds[["latitude", "longitude"]].values
population = sub_ds["level5"].values

for (lat, lon), pop in zip(coord, population):
    if lat != 0 and lon != 0:
        marker = Marker(location=(lat, lon))
        map.add_layer(marker)
    else:
        continue
map
## PUT HERE YOUR CODE:
# Out:
# Map(bottom=497.0, center=[60, -2.2], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title…
